# %%
print("                  TWO CLASS STUDENTS MARK ANALYSE   ")
print("\n")
import pandas as pd
data = pd.read_excel("C:/Users/PRADEEP PRIYA/Desktop/hw(excel sheet).xlsx")
print("                              CLASSROOM 1               ","\n")
data.classroom1.mean()
print("classroom1 has the mean:",data.classroom1.mean())
data.classroom1.median()
print("classroom1 has the median:",data.classroom1.median())
data.classroom1.mode()
print("classroom1 has the mode:",data.classroom1.mode())
data.classroom1.max()
print("classroom1 has the maximum:",data.classroom1.max())
data.classroom1.min()
print("classroom1 has the minimum:",data.classroom1.min())
rangedata = data.classroom1.max()-data.classroom1.min()
print("classroom1 has the range:",rangedata)
data.classroom1.std()
print("classroom1 has the standard deviation:",data.classroom1.std())
data.classroom1.skew()
print("classroom1 has the skewness:",data.classroom1.skew())
if((data.classroom1.skew() > -3)and (data.classroom1.skew()< +3)):
    print("classroom1 skewness is normal")
else:
    print("classroom1 skewness is abnormal")
data.classroom1.kurtosis()
print("classroom1 has the kurtosis:",data.classroom1.kurtosis())
if((data.classroom1.kurtosis() > -3) and (data.classroom1.kurtosis()< +3)):
    print("classroom1 kurtosis is normal")
else:
    print("classroom1 kurtosis is abnormal")
print("\n")
print("                              CLASSROOM 2               ","\n")
data.classroom2.mean()
print("classroom2 has the mean:",data.classroom2.mean())
data.classroom2.median()
print("classroom2 has the median:",data.classroom2.median())
data.classroom2.mode()
print("classroom2 has the mode:",data.classroom2.mode())
data.classroom2.max()
print("classroom2 has the maximum:",data.classroom2.max())
data.classroom2.min()
print("classroom2 has the minimum:",data.classroom2.min())
rangedata = data.classroom2.max()-data.classroom2.min()
print("classroom2 has the range:",rangedata)
data.classroom2.std()
print("classroom2 has the standard deviation:",data.classroom2.std())
data.classroom2.skew()
print("classroom2 has the skewness:",data.classroom2.skew())
if((data.classroom2.skew() > -3)and (data.classroom2.skew()< +3)):
    print("classroom2 skewness is normal")
else:
    print("classroom2 skewness is abnormal")
data.classroom2.kurtosis()
print("classroom2 has the kurtosis:",data.classroom2.kurtosis())
if((data.classroom2.kurtosis() > -3) and (data.classroom2.kurtosis()< +3)):
    print("classroom2 kurtosis is normal")
else:
    print("classroom2 kurtosis is abnormal")
print("\n")
print("                              BY ANALYSING THE ABOVE DATA                  ")
if(data.classroom1.mean() > data.classroom2.mean()):
    print("classroom1 has highest mean")
else:
    print("classroom2 has highest mean")
if(data.classroom1.median() > data.classroom2.median()):
    print("classroom1 has highest median")
else:
    print("classroom2 has highest median")
if(data.classroom1.max() > data.classroom2.max()):
    print("classroom1 has highest maximum")
else:
    print("classroom2 has highest maximum")
if(data.classroom1.min() > data.classroom2.min()):
    print("classroom1 has highest minimum")
else:
    print("classroom2 has highest minimum")
if((data.classroom1.max()-data.classroom1.min())>(data.classroom2.max()-data.classroom2.min())):
    print("classroom1 has more range")
else:
    print("classroom2 has more range")
if(data.classroom1.std() > data.classroom2.std()):
    print("classroom1 has more standard deviation")
else:
    print("classroom2 has more standard deviation")
print("\n")
if(data.classroom1.std() < data.classroom2.std()) :
    print("\n","                     'CLASSROOM 1 HAS SCORED GOOD RESULT'            ")
else:
    print("\n","                     'CLASSROOM 2 HAS SCORED GOOD RESULT'            ")
# Out:
#                   TWO CLASS STUDENTS MARK ANALYSE
#
#
#                               CLASSROOM 1
#
# classroom1 has the mean: 70.65
# classroom1 has the median: 68.0
# classroom1 has the mode: 0    67
# 1    71
# dtype: int64
# classroom1 has the maximum: 100
# classroom1 has the minimum: 45
# classroom1 has the range: 55
# classroom1 has the standard deviation: 18.06210047818942
# classroom1 has the skewness: 0.2109538781729716
# classroom1 skewness is normal
# classroom1 has the kurtosis: -1.2204291963798548
# classroom1 kurtosis is normal
#
#
#                               CLASSROOM 2
#
# classroom2 has the mean: 71.05
# classroom2 has the median: 74.0
# classroom2 has the mode: 0    73
# 1    75
# 2    76
# dtype: int64
# classroom2 has the maximum: 100
# classroom2 has the minimum: 35
# classroom2 has the range: 65
# classroom2 has the standard deviation: 18.96388534473938
# classroom2 has the skewness: -0.255218657693606
# classroom2 skewness is normal
# ...
